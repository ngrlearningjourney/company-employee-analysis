# %% [markdown]
# 👩‍💻 **Welcome to My Employee Retention and Attrition Analysis Portfolio!** 🏢
# What drives employees to stay, grow, or leave a company? In this project, I explored a compelling dataset sourced from Kaggle, packed with details about employee demographics, educational backgrounds 🎓, work history 📋, and employment-related factors. This dataset served as the foundation for uncovering actionable insights into workforce dynamics and retention strategies.
#
# To kick things off, I conducted **data wrangling** 🛠️ to ensure the dataset was clean and reliable. This involved addressing missing values, refining formats, and removing duplicates for clarity and consistency. With the data prepped, I dove into **Exploratory Data Analysis (EDA)** 🔍, uncovering fascinating patterns and trends in employee retention, attrition, and workforce management.
#
# Through this analysis, I aimed to answer critical questions, such as:
#
# ### 🌟 **Retention and Attrition Insights**
# - How many employees of each education degree have left the company, and how many have stayed?
# - Which education degree is most commonly associated with employees being benched?
# - What are the payment tiers for employees who were benched?
#
# ### 📊 **Workforce Composition and Tenure**
# - How many employees were recruited each year?
# - What is the average age of employees for each education degree?
# - What is the average years of experience for employees of each education degree?
# - For employees who left the company, what was their average years of experience?
#
# ### 🛠️ **Machine Learning Insights**
# In addition to analysis, I ventured into predictive analytics by building **classification machine learning models** to predict employee attrition. Using **K-Nearest Neighbors (KNN)** and **Logistic Regression**, I achieved accuracy scores of **71.8%** and **66.7%**, respectively. These models highlight the potential of data-driven decision-making in addressing workforce challenges.
#
# By answering these questions, I uncovered compelling insights, such as:
# - The challenges of retaining Master’s degree holders despite their expertise.
# - The high attrition rate among experienced employees, emphasizing the need for better growth opportunities.
# - Inefficiencies in workforce allocation, particularly among benched employees in lower payment tiers.
#
# ### **Key Recommendations:**
# - **Retention Strategies:** Tailored growth opportunities for Master’s degree holders and experienced employees.
# - **Experience Gaps:** Structured onboarding and mentorship programs to upskill employees with limited domain experience.
# - **Bench Optimization:** Reevaluate hiring practices and focus on aligning workforce needs with actual demand.
#
# From raw data to predictive insights, this project demonstrates the power of **analytics** and **machine learning** in decoding employee behavior and enhancing workforce management. Let’s dive in! ✨

# %% [markdown]
# # Gathering Data
#
# Data Source: https://www.kaggle.com/datasets/tawfikelmetwally/employee-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee_df = pd.read_csv('/Users/anakagungngurahanandasuryawedhana/Documents/learning material/DS/surya-wedhana-data-analysis-portofolio/Employee.csv')
# we turn the dataset into csv so we can explore the data

# %%
employee_df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# # Data Wrangling

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %% [markdown]
# **Dataset Analysis**
#
# - The dataset contains no missing values, ensuring data completeness.
# - All columns are in the correct format, ready for analysis.

# %%
print(employee_df.duplicated().sum())
# Out:
# 1889

# %% [markdown]
# The code identifies a total of 1,889 duplicate rows in the dataset.

# %%
employee_df.drop_duplicates(inplace=True)

# %% [markdown]
# To minimize bias during data analysis, the optimal approach is to remove duplicate values from the dataset.

# %%
### IQR Method ###
# Calculate Q1, Q3, and IQR
Q1 = np.percentile(employee_df['Age'], 25)
Q3 = np.percentile(employee_df['Age'], 75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
iqr_outliers = employee_df[(employee_df["Age"] < lower_bound) | (employee_df["Age"] > upper_bound)]

# %%
iqr_outliers
# Out:
# Empty DataFrame
# Columns: [Education, JoiningYear, City, PaymentTier, Age, Gender, EverBenched, ExperienceInCurrentDomain, LeaveOrNot]
# Index: []

# %% [markdown]
# After applying the IQR formula to detect outliers, the results confirm that the dataset contains no outliers.

# %%
employee_df.describe(include = 'all')
# Out:
#         Education  JoiningYear       City  PaymentTier          Age Gender  \
# count        2764  2764.000000       2764  2764.000000  2764.000000   2764
# unique          3          NaN          3          NaN          NaN      2
# top     Bachelors          NaN  Bangalore          NaN          NaN   Male
# freq         1971          NaN       1171          NaN          NaN   1529
# mean          NaN  2015.090449        NaN     2.636035    30.952967    NaN
# std           NaN     1.885943        NaN     0.624001     5.108872    NaN
# min           NaN  2012.000000        NaN     1.000000    22.000000    NaN
# 25%           NaN  2013.000000        NaN     2.000000    27.000000    NaN
# 50%           NaN  2015.000000        NaN     3.000000    30.000000    NaN
# 75%           NaN  2017.000000        NaN     3.000000    35.000000    NaN
# max           NaN  2018.000000        NaN     3.000000    41.000000    NaN
#
#        EverBenched  ExperienceInCurrentDomain   LeaveOrNot
# ...

# %% [markdown]
# **Insights from `.describe()` Function**
#
# Based on the summary statistics from the `.describe()` function, we can observe the following key insights about the employees in this company:
#
# 1. **Educational Qualifications**
#    Employees hold three different types of educational qualifications, with the majority having a bachelor's degree.
#
# 2. **Joining Year**
#    The most recent year an employee joined the company is **2018**.
#
# 3. **Employee Locations**
#    Employees in this company are based in **three different cities**.
#
# 4. **Age Range**
#    The employees' ages range from **22 to 41 years old**.
#
# 5. **Experience in Current Domain**
#    - The average experience in the current domain is **2.6 years**.
#    - The minimum experience is **1.6 years**, while the maximum experience is **7 years**.

# %%
employee_df = employee_df.reset_index()

# %%
employee_df.rename(columns={
 "index" : "employee_id"
}, inplace = True)

employee_df
# Out:
#       employee_id  Education  JoiningYear       City  PaymentTier  Age  \
# 0               0  Bachelors         2017  Bangalore            3   34
# 1               1  Bachelors         2013       Pune            1   28
# 2               2  Bachelors         2014  New Delhi            3   38
# 3               3    Masters         2016  Bangalore            3   27
# 4               4    Masters         2017       Pune            3   24
# ...           ...        ...          ...        ...          ...  ...
# 2759         4645    Masters         2017       Pune            2   31
# 2760         4647  Bachelors         2016       Pune            3   30
# 2761         4649    Masters         2013       Pune            2   37
# 2762         4650    Masters         2018  New Delhi            3   27
# 2763         4651  Bachelors         2012  Bangalore            3   30
#
#       Gender EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
for x in employee_df.columns:
  print(employee_df[x].unique())
# Out:
# [   0    1    2 ... 4649 4650 4651]
# ['Bachelors' 'Masters' 'PHD']
# [2017 2013 2014 2016 2015 2012 2018]
# ['Bangalore' 'Pune' 'New Delhi']
# [3 1 2]
# [34 28 38 27 24 22 23 37 32 39 29 30 36 31 25 26 40 35 33 41]
# ['Male' 'Female']
# ['No' 'Yes']
# [0 3 2 5 1 4 7 6]
# [0 1]

# %% [markdown]
# By using the `unique` method to inspect each column in the dataset, we confirmed that there are no misspellings or incorrect values in the data.

# %% [markdown]
# # EDA

# %%
employee_df.head(5)
# Out:
#    employee_id  Education  JoiningYear       City  PaymentTier  Age  Gender  \
# 0            0  Bachelors         2017  Bangalore            3   34    Male
# 1            1  Bachelors         2013       Pune            1   28  Female
# 2            2  Bachelors         2014  New Delhi            3   38  Female
# 3            3    Masters         2016  Bangalore            3   27    Male
# 4            4    Masters         2017       Pune            3   24    Male
#
#   EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# 0          No                          0           0
# 1          No                          3           1
# 2          No                          2           0
# 3          No                          5           1
# 4         Yes                          2           1

# %%
working_employee_df = employee_df[employee_df['LeaveOrNot'] == 0]
# gathering all employee that still working into one dataframe

# %%
working_employee_df.groupby(by="Education").employee_id.nunique().sort_values(ascending=False)
# Out:
# Education
# Bachelors    1232
# Masters       328
# PHD           116
# Name: employee_id, dtype: int64

# %%
education_df = working_employee_df.groupby(by="Education").employee_id.nunique().sort_values(ascending=False).reset_index()
education_df.columns = ['Education', 'NumberofEmployee']
education_df

# turn the groupby series into a dataframe
# Out:
#    Education  NumberofEmployee
# 0  Bachelors              1232
# 1    Masters               328
# 2        PHD               116

# %%
sns.barplot(y=education_df['Education'], x = education_df['NumberofEmployee'], orient='h', color='blue')
plt.xlabel('The Number of Employee')
plt.title('Employee From Each Degree')
plt.show()

# %% [markdown]
# Employee Educational Qualifications
#
# - **Bachelor's Degree**: The majority of employees hold a bachelor's degree, with a total of **1,232 individuals**.
# - **Master's Degree**: Employees with a master's degree number **328 individuals**.
# - **PhD**: Employees holding a PhD make up **116 individuals** in the company.

# %%
working_employee_df.groupby(by="Gender").employee_id.nunique().sort_values(ascending=False)
# Out:
# Gender
# Male      1055
# Female     621
# Name: employee_id, dtype: int64

# %%
gender_df = working_employee_df.groupby(by="Gender").employee_id.nunique().sort_values(ascending=False).reset_index()
gender_df.columns = ['Gender', 'NumberofEmployee']
gender_df
# Out:
#    Gender  NumberofEmployee
# 0    Male              1055
# 1  Female               621

# %%
colors = ('#8B4513', '#FFF8DC', '#93C572')
plt.pie(
    x = gender_df['NumberofEmployee'],
    labels = gender_df['Gender'],
    autopct = '%1.1f%%',
    colors = colors,
)
plt.title('Employee Gender Ratio')
plt.show()

# %% [markdown]
# **Employee Gender Distribution**
#
# - **Male Workers**: The total number of male employees is **1,529**, accounting for **62.9% of the total workforce**.
# - **Female Workers**: The total number of female employees is **1,235**, making up the remainder of the workforce.

# %%
working_employee_df.groupby(by="City").employee_id.nunique().sort_values(ascending=False)
# Out:
# City
# Bangalore    761
# New Delhi    522
# Pune         393
# Name: employee_id, dtype: int64

# %%
city_df = working_employee_df.groupby(by="City").employee_id.nunique().sort_values(ascending=False).reset_index()
city_df.columns = ['City', 'NumberofEmployee']
city_df
# Out:
#         City  NumberofEmployee
# 0  Bangalore               761
# 1  New Delhi               522
# 2       Pune               393

# %%
sns.barplot(y=city_df['NumberofEmployee'], x = city_df['City'], orient='v', color='blue')
plt.title("The Employee's Cities")
plt.show()

# %% [markdown]
# **Employee Locations**
#
# Employees in this company are distributed across the following cities:
# - **Bangalore**: **761 employees**
# - **Pune**: **522 employees**
# - **New Delhi**: **393 employees**

# %%
employee_df.groupby(by="EverBenched").employee_id.nunique().sort_values(ascending=False)
# Out:
# EverBenched
# No     2403
# Yes     361
# Name: employee_id, dtype: int64

# %%
everBenched_df = employee_df.groupby(by="EverBenched").employee_id.nunique().sort_values(ascending=False).reset_index()
everBenched_df.columns = ['EverBenched', 'NumberofEmployee']
everBenched_df
# Out:
#   EverBenched  NumberofEmployee
# 0          No              2403
# 1         Yes               361

# %%
sns.barplot(y=everBenched_df['NumberofEmployee'], x = everBenched_df['EverBenched'], orient='v', color='blue')
plt.title("EverBench")
plt.show()

# %% [markdown]
# **Employees Without Assigned Work**
#
# - The total number of employees who have been temporarily without assigned work is **361 individuals**.

# %%
# this is for calcualting correlation

from sklearn.preprocessing import LabelEncoder

ordinal_encoding_df = employee_df.copy()
label_encoder = LabelEncoder()

# Apply LabelEncoder to each categorical column
ordinal_encoding_df['Education'] = label_encoder.fit_transform(ordinal_encoding_df['Education'])
ordinal_encoding_df['City'] = label_encoder.fit_transform(ordinal_encoding_df['City'])
ordinal_encoding_df['EverBenched'] = label_encoder.fit_transform(ordinal_encoding_df['EverBenched'])
ordinal_encoding_df['Gender'] = label_encoder.fit_transform(ordinal_encoding_df['Gender'])

ordinal_encoding_df
# Out:
#       employee_id  Education  JoiningYear  City  PaymentTier  Age  Gender  \
# 0               0          0         2017     0            3   34       1
# 1               1          0         2013     2            1   28       0
# 2               2          0         2014     1            3   38       0
# 3               3          1         2016     0            3   27       1
# 4               4          1         2017     2            3   24       1
# ...           ...        ...          ...   ...          ...  ...     ...
# 2759         4645          1         2017     2            2   31       0
# 2760         4647          0         2016     2            3   30       1
# 2761         4649          1         2013     2            2   37       1
# 2762         4650          1         2018     1            3   27       1
# 2763         4651          0         2012     0            3   30       1
#
#       EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# ...

# %% [markdown]
# # Question

# %% [markdown]
# ## **How many employees of each education degree have left the company, and how many have stayed?**

# %%
# How many employee of each degree that leave the company and how much is not?
leave_or_not_mapping = {
    1 : "Leave",
    0 : "Not Leave"
}

def replaceLeaveorNot(LeaveOrNot):
    return leave_or_not_mapping.get(LeaveOrNot)

employee_df['LeaveOrNot'] = employee_df['LeaveOrNot'].apply(replaceLeaveorNot)
employee_df.head(5)
# Out:
#    employee_id  Education  JoiningYear       City  PaymentTier  Age  Gender  \
# 0            0  Bachelors         2017  Bangalore            3   34    Male
# 1            1  Bachelors         2013       Pune            1   28  Female
# 2            2  Bachelors         2014  New Delhi            3   38  Female
# 3            3    Masters         2016  Bangalore            3   27    Male
# 4            4    Masters         2017       Pune            3   24    Male
#
#   EverBenched  ExperienceInCurrentDomain LeaveOrNot
# 0          No                          0  Not Leave
# 1          No                          3      Leave
# 2          No                          2  Not Leave
# 3          No                          5      Leave
# 4         Yes                          2      Leave

# %%
employee_df.groupby(by=["Education","LeaveOrNot"]).agg({
    "employee_id" : "count"
}).sort_values(by="employee_id", ascending=False)
# Out:
#                       employee_id
# Education LeaveOrNot
# Bachelors Not Leave          1232
#           Leave               739
# Masters   Not Leave           328
#           Leave               309
# PHD       Not Leave           116
#           Leave                40

# %%
education_leaveornot_df = employee_df.groupby(by=["Education","LeaveOrNot"]).agg({
    "employee_id" : "count"
}).sort_values(by="employee_id", ascending=False).reset_index()
education_leaveornot_df.columns = ['Education','LeaveOrNot' ,'NumberofEmployee']

# %%
sns.barplot(data = education_leaveornot_df, x='Education', y="NumberofEmployee", hue="LeaveOrNot", errorbar=None)
plt.title('Comparing Each Degree From Employee')
plt.ylabel('Number Of Employee')
plt.show()

# %% [markdown]
# From the analysis above, we can conclude:
# 1. **1,232 employees with a Bachelor's degree** have remained with the company.
# 2. **328 employees with a Master's degree** have remained with the company.
# 3. **116 employees with a PhD** have remained with the company.
#
# Regarding employees who have left the company:
# 1. **739 employees with a Bachelor's degree** have left the company.
# 2. **309 employees with a Master's degree** have left the company.
# 3. **40 employees with a PhD** have left the company.

# %% [markdown]
# ## **How many employees were recruited each year?**

# %%
employee_df.groupby(by=['JoiningYear']).agg({
    'employee_id' : 'count'
})
# Out:
#              employee_id
# JoiningYear
# 2012                 308
# 2013                 396
# 2014                 385
# 2015                 464
# 2016                 310
# 2017                 662
# 2018                 239

# %%
employee_df.groupby(by=['JoiningYear','Education']).agg({
    'employee_id' : 'count'
})
# Out:
#                        employee_id
# JoiningYear Education
# 2012        Bachelors          254
#             Masters             41
#             PHD                 13
# 2013        Bachelors          285
#             Masters             78
#             PHD                 33
# 2014        Bachelors          306
#             Masters             61
#             PHD                 18
# 2015        Bachelors          347
#             Masters             85
#             PHD                 32
# 2016        Bachelors          254
#             Masters             39
#             PHD                 17
# 2017        Bachelors          367
#             Masters            277
#             PHD                 18
# 2018        Bachelors          158
#             Masters             56
#             PHD                 25

# %%
joiningyear_education_df = employee_df.groupby(by=['JoiningYear','Education']).agg({
    'employee_id' : 'count'
}).reset_index()

joiningyear_education_df.rename(columns={
    "employee_id" : "NumberofEmployee"
}, inplace=True)

joiningyear_education_df
# Out:
#     JoiningYear  Education  NumberofEmployee
# 0          2012  Bachelors               254
# 1          2012    Masters                41
# 2          2012        PHD                13
# 3          2013  Bachelors               285
# 4          2013    Masters                78
# 5          2013        PHD                33
# 6          2014  Bachelors               306
# 7          2014    Masters                61
# 8          2014        PHD                18
# 9          2015  Bachelors               347
# 10         2015    Masters                85
# 11         2015        PHD                32
# 12         2016  Bachelors               254
# 13         2016    Masters                39
# 14         2016        PHD                17
# 15         2017  Bachelors               367
# 16         2017    Masters               277
# 17         2017        PHD                18
# 18         2018  Bachelors               158
# 19         2018    Masters                56
# ...

# %%
bachelors_df = joiningyear_education_df[joiningyear_education_df['Education'] == 'Bachelors']
masters_df = joiningyear_education_df[joiningyear_education_df['Education'] == 'Masters']
phd_df = joiningyear_education_df[joiningyear_education_df['Education'] == 'PHD']

# plot lines
plt.plot(bachelors_df['JoiningYear'], bachelors_df['NumberofEmployee'], label = "Bachelors")
plt.plot(masters_df['JoiningYear'], masters_df['NumberofEmployee'], label = "Masters")
plt.plot(phd_df['JoiningYear'], phd_df['NumberofEmployee'], label = "PHD")
plt.legend()
plt.show()

# %% [markdown]
# From the table above we know
#
# 1. in 2012, we hire 308 individuals
# 2. in 2013, we hire 396 individuals
# 3. in 2014, we hire 385 individuals
# 4. in 2015, we hire 464 individuals
# 5. in 2016, we hire 310 individuals
# 6. in 2017, we hire 662 individuals
# 7. in 2018, we hire 239 individuals
#
# Employee Hiring Trends
#
# 1. The highest number of employees were hired in **2017**, including:
#    - **367 Bachelor's degree holders**
#    - **227 Master's degree holders**
#    - **28 PhD holders**
#
# 2. The highest number of **Bachelor's** and **Master's** degree holders were hired in **2017**, with **367** and **227 individuals**, respectively.
# 3. The highest number of **PhD holders** were hired in **2013**, with **33 individuals**.

# %% [markdown]
# ## **What is the average age of employees for each education degree?**

# %%
# What is the average employee age from each education degree
working_employee_df.groupby(by="Education").agg({
    'Age' : ['min', 'max','mean']
})
# Out:
#           Age
#           min max       mean
# Education
# Bachelors  22  41  31.718344
# Masters    23  41  31.000000
# PHD        22  41  29.525862

# %% [markdown]
# **Age Range by Educational Qualification**
#
# - **Bachelor's Degree**: The youngest holder is **22 years old**, and the oldest is **41 years old**.
# - **Master's Degree**: The youngest holder is **23 years old**, and the oldest is **41 years old**.
# - **PhD**: The youngest holder is **22 years old**, and the oldest is **41 years old**.

# %% [markdown]
# ## **What is the average years of experience for employees of each education degree?**

# %%
employee_df[employee_df['LeaveOrNot'] == 'Not Leave'].groupby(by='Education').agg({
    'ExperienceInCurrentDomain' : ['min','max','mean']
})
# Out:
#           ExperienceInCurrentDomain
#                                 min max      mean
# Education
# Bachelors                         0   7  2.676136
# Masters                           0   5  2.579268
# PHD                               0   5  2.887931

# %%
employee_without_working_exp_df = employee_df[employee_df['ExperienceInCurrentDomain'] == 0]
employee_without_working_exp_df.groupby(by='Education').agg({
    'employee_id' : 'count'
})
# Out:
#            employee_id
# Education
# Bachelors          239
# Masters             35
# PHD                 13

# %% [markdown]
# **Analysis Summary: Experience in Current Position**
#
# - **Maximum Years of Experience:**
#   - Bachelor's degree holders: 7 years
#   - Master's degree holders: 5 years
#   - Ph.D. holders: 5 years
#
# - **Minimum Years of Experience:**
#   - All education levels: 0 years
#
# - **Individuals with No Experience in Their Current Domain:**
#   - Bachelor's degree holders: **239**
#   - Master's degree holders: **35**
#   - Ph.D. holders: **13**

# %% [markdown]
# ## **For employees who left the company, what was their average years of experience?**

# %%
employee_already_left = employee_df[employee_df['LeaveOrNot'] == 'Leave']

employee_already_left.groupby(by='Education').agg({
    'ExperienceInCurrentDomain' : ['min','max']
})
# Out:
#           ExperienceInCurrentDomain
#                                 min max
# Education
# Bachelors                         0   7
# Masters                           0   7
# PHD                               0   5

# %%
employee_already_left[employee_already_left['ExperienceInCurrentDomain'] > 3].groupby(by='Education').agg({
    'employee_id' : 'count'
})
# Out:
#            employee_id
# Education
# Bachelors          208
# Masters            113
# PHD                 11

# %% [markdown]
# **Employee Attrition Analysis: Experience and Education**
#
# - **Experience Range of Employees Who Left:**
#   Employees who left the company had between **0 to 7 years** of experience.
#
# - **Employees with Over 3 Years of Experience Who Left, by Education Level:**
#   - **Bachelor's degree holders:** **208**
#   - **Master's degree holders:** **113**
#   - **Ph.D. holders:** **11**

# %% [markdown]
# ## **Which education degree is most commonly associated with employees being benched?**

# %%
employee_df[employee_df['EverBenched'] == 'Yes'].groupby(by='Education').employee_id.nunique()
# Out:
# Education
# Bachelors    286
# Masters       72
# PHD            3
# Name: employee_id, dtype: int64

# %% [markdown]
# **Employee Bench Analysis**
#
# - **Total Employees Benched by Education Level:**
#   - **Bachelor's degree holders:** **286** (highest)
#   - **Master's degree holders:** **72**
#   - **Ph.D. holders:** **3**

# %% [markdown]
# ## **Display the payment tiers for employees who were benched.**

# %%
employee_df[employee_df['EverBenched'] == 'Yes'].groupby(by='PaymentTier').employee_id.nunique()
# Out:
# PaymentTier
# 1     18
# 2     62
# 3    281
# Name: employee_id, dtype: int64

# %% [markdown]
# **Bench Analysis by Payment Tier**
#
# - **Employees Benched by Payment Tier:**
#   1. **Payment Tier 3:** Highest number of benched employees
#   2. **Payment Tier 2:** Second highest number of benched employees
#   3. **Payment Tier 1:** Lowest number of benched employees

# %% [markdown]
# ## **Which Column Has the Highest Correlation in Predicting Whether an Employee Will Leave?**

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()

employee_df['LeaveOrNot'] = label_encoder.fit_transform(employee_df['LeaveOrNot'])
numerical_columns = employee_df[['Age','ExperienceInCurrentDomain','JoiningYear']]


from scipy.stats import pointbiserialr

correlations = []
for column in numerical_columns:
  correlation, p_value = pointbiserialr(employee_df[column], employee_df['LeaveOrNot'])
  correlations.append(correlation)

data = {
    'numerical_columns': numerical_columns.columns,
    'correlations': correlations
}
numerical_columns_correlations = pd.DataFrame(data)
numerical_columns_correlations.sort_values(by='correlations', ascending=False)
# Out:
#            numerical_columns  correlations
# 0                        Age      0.114943
# 1  ExperienceInCurrentDomain      0.021181
# 2                JoiningYear     -0.150650

# %% [markdown]
# **Correlation Summary with `LeaveOrNot`**
#
# **Key Points:**
# 1. **Age** shows a weak positive correlation (*0.114943*) with `LeaveOrNot`, suggesting that as age increases, there is a slight tendency for employees to leave.
# 2. **ExperienceInCurrentDomain** has a very weak positive correlation (*0.021181*) with `LeaveOrNot`, indicating little to no relationship between experience in the current domain and leaving.
# 3. **JoiningYear** has a weak negative correlation (*-0.150650*), meaning employees who joined earlier are slightly less likely to leave.
#
# While these correlations are weak, they may still provide insights into employee behavior trends.

# %%
nominal_columns = ['City','Gender', 'EverBenched']

# Fit and transform the categorical column to numeric values
for column in ordinal_columns:
  employee_df[column] = label_encoder.fit_transform(employee_df[column])

employee_df['Education'] = label_encoder.fit_transform(employee_df['Education'])

# %%
from scipy.stats import chi2_contingency
import pandas as pd

chiResult = []
pValue = []
cramer_v = []

for column in nominal_columns:
    # Create a contingency table
    contingency_table = pd.crosstab(employee_df[column], employee_df['LeaveOrNot'])

    # Perform Chi-Square Test (unpacking the 4 values)
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    # Calculate Cramér's V
    n = contingency_table.to_numpy().sum()  # Total number of observations
    min_dim = min(contingency_table.shape) - 1  # Minimum dimension minus 1
    cramers_v = np.sqrt(chi2 / (n * min_dim))

    # Append the chi2 and p values to their respective lists
    chiResult.append(chi2)
    pValue.append(p)
    cramer_v.append(cramers_v)

# Prepare the results in a DataFrame
data = {
    'nominal_columns': nominal_columns,
    'Chi-Square Statistic': chiResult,
    'P-value': pValue,
    'Cramer v' : cramer_v
}
numerical_columns_correlations = pd.DataFrame(data)
numerical_columns_correlations
# Out:
#   nominal_columns  Chi-Square Statistic       P-value  Cramer v
# 0            City             63.456311  1.662024e-14  0.151519
# 1          Gender             99.478655  1.982889e-23  0.189712
# 2     EverBenched              3.589789  5.813562e-02  0.036038

# %% [markdown]
# **Chi-Square Test and Cramér's V Summary**
#
# | Column         | Chi-Square Statistic | P-value          | Cramér's V | Interpretation                              |
# |----------------|----------------------|------------------|------------|----------------------------------------------|
# | **City**       | 63.46               | 1.66e-14         | 0.1515     | Significant weak to moderate correlation     |
# | **Gender**     | 99.48               | 1.98e-23         | 0.1897     | Significant weak to moderate correlation     |
# | **EverBenched**| 3.59                | 0.058            | 0.0360     | Not significant; negligible correlation      |
#
# **Key Points:**
# 1. **City** and **Gender** show statistically significant relationships with `LeaveOrNot` (p-value < 0.05).
# 2. Both `City` and `Gender` exhibit weak to moderate associations (Cramér's V < 0.3).
# 3. **EverBenched** does not show a significant relationship with `LeaveOrNot` (p-value > 0.05) and has a negligible association (Cramér's V = 0.036).

# %%
from scipy.stats import kendalltau
ordinal_columns = ['Education', 'PaymentTier']
tau_values = []
p_values = []
for column in ordinal_columns:
  # Calculate Kendall's Tau-b correlation
  tau, p_value = kendalltau(employee_df[column], employee_df['LeaveOrNot'])
  tau_values.append(tau)
  p_values.append(p_value)

# Prepare the results in a DataFrame
data = {
    'ordinal_columns': ordinal_columns,
    'Kendall Tau': tau_values,
    'P-value': p_values,
}

ordinal_columns_correlations = pd.DataFrame(data)
ordinal_columns_correlations
# Out:
#   ordinal_columns  Kendall Tau       P-value
# 0       Education    -0.045448  1.462472e-02
# 1     PaymentTier     0.155714  4.093290e-17

# %% [markdown]
# **Kendall's Tau Correlation Summary**
#
# | Column         | Kendall Tau | P-value          | Interpretation                              |
# |----------------|-------------|------------------|---------------------------------------------|
# | **Education**  | -0.0454     | 1.46e-02         | Weak negative correlation, statistically significant |
# | **PaymentTier**| 0.1557      | 4.09e-17         | Weak positive correlation, statistically significant |
#
# **Key Points:**
# 1. Both **Education** and **PaymentTier** have statistically significant correlations with `LeaveOrNot` (p-value < 0.05).
# 2. **Education** shows a weak negative correlation, meaning as education level changes, there is a slight tendency for the likelihood of `LeaveOrNot` to move inversely.
# 3. **PaymentTier** shows a weak positive correlation, indicating that higher payment tiers are slightly associated with increased likelihood of `LeaveOrNot`.

# %% [markdown]
# ### Recap of Correlation Summary with `LeaveOrNot`
#
# - **Age**: Weak positive correlation (*0.114943*) — Older employees are slightly more likely to leave.
# - **ExperienceInCurrentDomain**: Very weak positive correlation (*0.021181*) — Little to no impact on leaving.
# - **JoiningYear**: Weak negative correlation (*-0.150650*) — Employees who joined earlier are marginally less likely to leave.
#
# ### Categorical Variables:
# - **City** and **Gender**: Statistically significant relationships with `LeaveOrNot` (p-value < 0.05) but weak to moderate associations (Cramér's V < 0.3).
# - **EverBenched**: No significant relationship (p-value > 0.05) and negligible association (Cramér's V = 0.036).
#
# ### Other Factors:
# - **Education**: Weak negative correlation — Higher education levels slightly reduce the likelihood of leaving.
# - **PaymentTier**: Weak positive correlation — Higher payment tiers are slightly associated with an increased likelihood of leaving.
#
# While all correlations are weak, they provide useful insights into trends affecting employee retention.

# %% [markdown]
# # Classification

# %%
# Replace specific categorical values in the DataFrame with numerical codes
# This is useful for preparing the data for machine learning models that require numerical inputs
employee_df = employee_df.replace(
    [
        'Bachelors', 'Masters', 'PHD',  # Education levels
        'Bangalore', 'Pune', 'New Delhi',  # Locations
        'Male', 'Female',  # Gender
        'No', 'Yes',  # Binary responses
        'Not Leave', 'Leave'  # Employee leave status
    ],
    [
        1, 2, 3,  # Numerical codes for education levels
        1, 2, 3,  # Numerical codes for locations
        1, 2,  # Numerical codes for gender
        1, 2,  # Numerical codes for binary responses
        1, 2   # Numerical codes for leave status
    ]
)

# %%
X = employee_df.iloc[:,:-1].values
y = employee_df.iloc[:,-1].values
# x is independent variable and y is dependent variable

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.1)
# Split the dataset into training and testing sets
# X: Features (input data)
# y: Target (output labels)
# test_size: Proportion of the dataset to include in the test split (10% in this case)
# X_train, X_test: Training and testing features
# y_train, y_test: Training and testing labels

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
# StandardScaler standardizes the data by removing the mean and scaling to unit variance
sc = StandardScaler()

# Fit the scaler to the training data and transform it
# This calculates the mean and standard deviation from X_train and applies scaling
X_train = sc.fit_transform(X_train)

# Transform the test data using the same scaling parameters calculated from the training data
# to ensure consistency between training and test data scaling.
X_test = sc.transform(X_test)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression classifier
# random_state: Ensures reproducibility by setting a fixed random seed
classifier = LogisticRegression(random_state=0)

# Fit the Logistic Regression model to the training data
# X_train: Training features
# y_train: Training labels
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Predict the labels for the test set using the trained classifier
# X_test: Features of the test set
# y_pred: The predicted labels for the test data
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Generate the confusion matrix to evaluate the performance of the classification model
# y_test: Actual labels of the test set
# y_pred: Predicted labels from the model
cm = confusion_matrix(y_test, y_pred)

# Print the confusion matrix to show the model's performance
print("Confusion Matrix\n", cm)

# Calculate and print the accuracy score, which is the proportion of correct predictions
# accuracy_score compares the actual and predicted labels
print("Accuracy score", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[ 64  59]
#  [ 16 138]]
# Accuracy score 0.7292418772563177

# %% [markdown]
# The accuracy score of 0.7292418772563177 (approximately 72%) is the proportion of correct predictions made by the model.

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize the K-Nearest Neighbors (KNN) classifier
# n_neighbors: Number of neighbors to consider when making a prediction (5 in this case)
# metric: The distance metric to use for calculating the distance between points ("euclidean" calculates the straight-line distance)
# p: Power parameter for the Minkowski distance metric (p=2 corresponds to Euclidean distance)
classifier = KNeighborsClassifier(n_neighbors=5, metric="euclidean", p=2)

# Fit the KNN model to the training data
# X_train: Training features
# y_train: Training labels
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Generate the confusion matrix to evaluate the performance of the KNN model
# y_test: Actual labels of the test set
# y_pred: Predicted labels from the KNN model
cm2 = confusion_matrix(y_test, y_pred)

# Print the confusion matrix to see the breakdown of the model's performance
print("Confusion Matrix\n", cm2)

# Calculate and print the accuracy score for the KNN model
# accuracy_score compares the actual labels (y_test) with the predicted labels (y_pred)
print("Accuracy Score: ", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[ 73  50]
#  [ 19 135]]
# Accuracy Score:  0.7509025270758123

# %% [markdown]
# Accuracy: 0.7509025270758123 (approximately 75%) The accuracy score indicates that the model correctly predicted the class labels 74% of the time.

# %% [markdown]
# # **Insight and Recommendation**
#
# **Insights**
#
# 1. **Employee Retention and Attrition by Education Level**
#    - Bachelor's degree holders constitute the majority of both retained (1,232) and departed (739) employees, indicating they form the largest group in the workforce.
#    - Master's degree holders show a moderate retention rate (328 stayed, 309 left), suggesting potential challenges in retaining this group.
#    - Ph.D. holders, while the smallest group, exhibit the highest retention rate relative to attrition (116 stayed, 40 left).
#
# 2. **Experience Analysis**
#    - Employees with Bachelor's degrees have the longest tenure, with a maximum of 7 years of experience, followed by Master's and Ph.D. holders (5 years each).
#    - A significant number of employees have no domain experience, particularly among Bachelor's degree holders (239), which might indicate entry-level hiring or mismatched roles.
#
# 3. **Attrition and Experience**
#   - Employees who left the company had between 0 and 7 years of experience, meaning attrition occurs across the entire range of tenure for all education levels.
#   - For employees with over 3 years of experience, Bachelor's degree holders form the majority of those leaving (208), followed by Master's degree holders (113) and Ph.D. holders (11).
#   - This suggests that while attrition isn't confined to a specific period, employees with substantial experience may leave due to unaddressed career aspirations or better opportunities elsewhere.
#
# 4. **Bench Analysis**
#    - Bachelor's degree holders have the highest number of benched employees (286), potentially due to over-hiring or misallocation of roles.
#    - Most benched employees belong to Payment Tier 3, followed by Tier 2 and Tier 1, which could indicate inefficiencies in managing lower-tier employees.
#
# ---
#
# **Recommendations**
#
# 1. **Improve Retention Strategies for Master's Degree Holders**
#    - Conduct exit interviews and satisfaction surveys to identify reasons for attrition among Master's degree holders.
#    - Offer tailored growth opportunities, such as leadership training or advanced technical skills, to better engage and retain them.
#
# 2. **Address Domain Experience Gaps**
#    - Provide structured onboarding and training programs to upskill employees with no prior domain experience, particularly among Bachelor's degree holders.
#    - Develop mentorship programs where experienced employees guide newcomers.
#
# 3. **Targeted Retention for Experienced Employees**
#    - Introduce incentives like promotions, salary increases, and career development plans for employees with more than 3 years of experience.
#    - Foster a strong organizational culture to encourage long-term commitment.
#
# 4. **Optimize Bench Management**
#    - Reevaluate hiring practices to prevent over-hiring, especially for roles requiring Bachelor's degrees.
#    - Assign benched employees to short-term projects, cross-training opportunities, or skill development programs to enhance their utilization.
#
# 5. **Payment Tier Utilization Strategy**
#    - Investigate the reasons for higher benching in Payment Tier 3 and focus on aligning hiring with actual workforce needs.
#    - Create pathways for employees in lower tiers to advance through internal training and certification programs, reducing benching rates.
